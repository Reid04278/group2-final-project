# %%
# Import Dependencies
import pandas as pd
import sklearn.preprocessing as skl
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import xgboost as xgb

# %%
# Read in the csv 
sales_df = pd.read_csv("Walmart.csv")
sales_df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
# Extract the date from the dataframe
sales_df['Date'] = pd.to_datetime(sales_df['Date'])
sales_df['Day'] = sales_df['Date'].dt.weekday
sales_df['Week'] = sales_df['Date'].dt.week
sales_df['Month'] = sales_df['Date'].dt.month
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1980\1628188651.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   sales_df['Date'] = pd.to_datetime(sales_df['Date'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1980\1628188651.py:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   sales_df['Week'] = sales_df['Date'].dt.week

# %%
sales_df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Day  Week  Month
# 0     211.096358         8.106    6    17      5
# 1     211.242170         8.106    3    48     12
# 2     211.289143         8.106    4     7      2
# 3     211.319643         8.106    4     8      2
# 4     211.350143         8.106    0    18      5
# ...          ...           ...  ...   ...    ...
# 6430  192.013558         8.684    4    39      9
# 6431  192.170412         8.667    3    19      5
# 6432  192.327265         8.667    0    50     12
# 6433  192.330854         8.667    4    42     10
# 6434  192.308899         8.667    4    43     10
#
# [6435 rows x 11 columns]

# %%
# Plot the weekly sales
weekly_sale = sales_df.groupby('Week')['Weekly_Sales'].sum()
plt.figure(figsize=(15, 9))
plt.plot(weekly_sale, marker='o', linestyle='-')

# %% [markdown]
# # Preprocessing

# %%
# dropping the date column
sales_df.drop('Date',axis=1,inplace=True)

# %%
# Use Preprocessing methods
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# Get our target and features arrays
y = sales_df['Weekly_Sales'].values
X = sales_df.drop('Weekly_Sales', axis=1).values
X_scaled = scaler.fit_transform(X)

# %%
# Split into testing and training set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=42)

# %%
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test)

# %% [markdown]
# # First XGBOOST Model

# %%
# Create the first XGBoost Model
params = {
    'objective': 'reg:squarederror',  # for regression
    'eval_metric': 'rmse',            # rmse for regression
    'eta': 0.1,                       # learning rate
    'max_depth': 3,                   # maximum depth of the tree
    'min_child_weight': 1,            # minimum sum of instance weight (hessian) needed in a child
    'gamma': 0,                       # minimum loss reduction required to make a further partition on a leaf node
    'subsample': 0.8,                 # subsample ratio of the training instance
    'colsample_bytree': 0.8,          # subsample ratio of columns when constructing each tree
    'seed': 42                        # random seed for reproducibility
}

# Train the regression model
num_rounds = 100  # Number of boosting rounds (iterations)
model = xgb.train(params, dtrain, num_rounds)

# %%
# Calculate accuracy
from sklearn.metrics import r2_score

# Make predictions
y_pred = model.predict(dtest)

# Calculate R-squared
r_squared = r2_score(y_test, y_pred)

print("R-squared:", r_squared)
# Out:
# R-squared: 0.9037557050115052

# %% [markdown]
# # Optimizing the Model

# %%
# Optimize the model by dropping colums from the dataframe, etc and calculate accuracy again

# %% [markdown]
# # Optimize model one more time (If haven't reached 75% accuracy)

# %%
# If accuracy is still not at 75% or higher, optimize the model one more time and calculate accuracy
